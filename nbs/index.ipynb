# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # nbsstorytime
#
# > Python Library to write N4L notes from Jupyter Notebooks

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install nbsstorytime in Development mode

# %% [markdown]
# ```sh
# # make sure nbsstorytime package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to nbsstorytime
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/chrphb/nbsstorytime.git
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install nbsstorytime
# ```
#
#
# [repo]: https://github.com/chrphb/nbsstorytime
# [docs]: https://chrphb.github.io/nbsstorytime/
# [pypi]: https://pypi.org/project/nbsstorytime/

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/chrphb/nbsstorytime
# [docs]: https://chrphb.github.io/nbsstorytime/
# [pypi]: https://pypi.org/project/nbsstorytime/
# [conda]: https://anaconda.org/chrphb/nbsstorytime

# %% [markdown]
# ## How to use

# %% [markdown]
# Example of a cell with N4L code:

# %% [raw]
# #| n4l
#
# - my notes     # you give it a title
#                # and you can leave comments to yourself.
#
# Mostly you just write notes
#     "  (e.g.)  This is a simple example that illustrates the line above
#
# The >ditto symbol of inverted commas has a special meaning
#
# Other symbols can be defined with your own meanings, like >"special meanings"

# %%
#| hide
import nbsstorytime; nbsstorytime.nbsstorytime_export()
# Out:
# no current notebook
